# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
url="https://www.imdb.com/title/tt0499549/reviews"

# %%
    page=requests.get(url)
    soup=BeautifulSoup(page.text,"html.parser")
    reviews=soup.find_all("div", class_="text show-more__control")
    reviews = soup.find_all("div", class_="text show-more__control")
    for review in reviews:
        review_text = review.get_text(strip=True)  # Get the text content, stripping any leading or trailing whitespaces
        print(review_text)
        print("---")
    print("\n\n *****************************************************************************************************")
# Out:
# I'm not exactly sure when it became a thing among my tribe of film geeks to bash 'Avatar'. I know it wasn't when it came out, because most of the film fans in my circle of nerdy friends went to watch it multiple times and couldn't get enough of it. In hindsight, I suspect it was around the time when everybody and their grandmother seemed to have seen it; somehow, once the film had become the most successful movie ever (unadjusted for inflation) it stopped being cool to like James Cameron's eco-sci-fi extravaganza.Nowadays the film is often brought up in snarky movie blogs as a typical example for a film with great effects but a dull story, unoriginal ideas and bland characters, as if this were somehow the general consensus among film aficionados. "FernGully in space" or "Dances With Wolves with blue cat-people" are some of the kinder descriptions the film has to endure - which in all honesty I don't get.I mean, it's fine not to like the movie (all art is subjective and all that), but
# ...

# %%
url1="https://www.imdb.com/title/tt0499549/reviews"

# %%
    page=requests.get(url1)
    soup=BeautifulSoup(page.text,"html.parser")
    reviews=soup.find_all("div", class_="text show-more__control")
    reviews = soup.find_all("div", class_="text show-more__control")
    for review in reviews:
        review_text = review.get_text(strip=True)  # Get the text content, stripping any leading or trailing whitespaces
        print(review_text)
        print("---")
    print("\n\n *****************************************************************************************************")
# Out:
# I'm not exactly sure when it became a thing among my tribe of film geeks to bash 'Avatar'. I know it wasn't when it came out, because most of the film fans in my circle of nerdy friends went to watch it multiple times and couldn't get enough of it. In hindsight, I suspect it was around the time when everybody and their grandmother seemed to have seen it; somehow, once the film had become the most successful movie ever (unadjusted for inflation) it stopped being cool to like James Cameron's eco-sci-fi extravaganza.Nowadays the film is often brought up in snarky movie blogs as a typical example for a film with great effects but a dull story, unoriginal ideas and bland characters, as if this were somehow the general consensus among film aficionados. "FernGully in space" or "Dances With Wolves with blue cat-people" are some of the kinder descriptions the film has to endure - which in all honesty I don't get.I mean, it's fine not to like the movie (all art is subjective and all that), but
# ...

# %%
    page=requests.get(url1)
    soup=BeautifulSoup(page.text,"html.parser")
    reviews=soup.find_all("div", class_="text show-more__control")
    reviews = soup.find_all("div", class_="text show-more__control")
with open(r"C:\Users\ritik\OneDrive\Documents\family Credentials\documents\Badshah\alma mater certificates\TISS Curriculum\mathematics\Avatar Movie Review.txt", "w", encoding="utf-8") as file:
    for review in reviews:
        review_text = review.get_text(strip=True)  # Get the text content, stripping any leading or trailing whitespaces
        print(review_text)
        print("---")
        file.write(review_text + "\n---\n")
    print("\n\n *****************************************************************************************************")
# Out:
#   Cell In[16], line 6
#     for review in reviews:
#     ^
# IndentationError: expected an indented block after 'with' statement on line 5

# %%
page = requests.get(url1)
soup = BeautifulSoup(page.text, "html.parser")
reviews = soup.find_all("div", class_="text show-more__control")

with open(r"C:\Users\ritik\OneDrive\Documents\family Credentials\documents\Badshah\alma mater certificates\TISS Curriculum\mathematics\Avatar Movie Review.txt", "w", encoding="utf-8") as file:
    for review in reviews:
        review_text = review.get_text(strip=True)  # Get the text content, stripping any leading or trailing whitespaces
        print(review_text)
        print("---")
        file.write(review_text + "\n---\n")

print("\n\n *****************************************************************************************************")
# Out:
# I'm not exactly sure when it became a thing among my tribe of film geeks to bash 'Avatar'. I know it wasn't when it came out, because most of the film fans in my circle of nerdy friends went to watch it multiple times and couldn't get enough of it. In hindsight, I suspect it was around the time when everybody and their grandmother seemed to have seen it; somehow, once the film had become the most successful movie ever (unadjusted for inflation) it stopped being cool to like James Cameron's eco-sci-fi extravaganza.Nowadays the film is often brought up in snarky movie blogs as a typical example for a film with great effects but a dull story, unoriginal ideas and bland characters, as if this were somehow the general consensus among film aficionados. "FernGully in space" or "Dances With Wolves with blue cat-people" are some of the kinder descriptions the film has to endure - which in all honesty I don't get.I mean, it's fine not to like the movie (all art is subjective and all that), but
# ...

# %%
with open(r"C:\Users\ritik\OneDrive\Documents\family Credentials\documents\Badshah\alma mater certificates\TISS Curriculum\mathematics\Avatar Movie Review.txt", 'r', encoding='utf-8') as file:
    text_data = file.read()

# %%
text_data
# Out:
# 'I\'m not exactly sure when it became a thing among my tribe of film geeks to bash \'Avatar\'. I know it wasn\'t when it came out, because most of the film fans in my circle of nerdy friends went to watch it multiple times and couldn\'t get enough of it. In hindsight, I suspect it was around the time when everybody and their grandmother seemed to have seen it; somehow, once the film had become the most successful movie ever (unadjusted for inflation) it stopped being cool to like James Cameron\'s eco-sci-fi extravaganza.Nowadays the film is often brought up in snarky movie blogs as a typical example for a film with great effects but a dull story, unoriginal ideas and bland characters, as if this were somehow the general consensus among film aficionados. "FernGully in space" or "Dances With Wolves with blue cat-people" are some of the kinder descriptions the film has to endure - which in all honesty I don\'t get.I mean, it\'s fine not to like the movie (all art is subjective and all t
# ...

# %%
text_data = text_data.lower()
text_data
# Out:
# 'i\'m not exactly sure when it became a thing among my tribe of film geeks to bash \'avatar\'. i know it wasn\'t when it came out, because most of the film fans in my circle of nerdy friends went to watch it multiple times and couldn\'t get enough of it. in hindsight, i suspect it was around the time when everybody and their grandmother seemed to have seen it; somehow, once the film had become the most successful movie ever (unadjusted for inflation) it stopped being cool to like james cameron\'s eco-sci-fi extravaganza.nowadays the film is often brought up in snarky movie blogs as a typical example for a film with great effects but a dull story, unoriginal ideas and bland characters, as if this were somehow the general consensus among film aficionados. "ferngully in space" or "dances with wolves with blue cat-people" are some of the kinder descriptions the film has to endure - which in all honesty i don\'t get.i mean, it\'s fine not to like the movie (all art is subjective and all t
# ...

# %%
text_data = text_data.lower()
text_data
# Out:
# 'i\'m not exactly sure when it became a thing among my tribe of film geeks to bash \'avatar\'. i know it wasn\'t when it came out, because most of the film fans in my circle of nerdy friends went to watch it multiple times and couldn\'t get enough of it. in hindsight, i suspect it was around the time when everybody and their grandmother seemed to have seen it; somehow, once the film had become the most successful movie ever (unadjusted for inflation) it stopped being cool to like james cameron\'s eco-sci-fi extravaganza.nowadays the film is often brought up in snarky movie blogs as a typical example for a film with great effects but a dull story, unoriginal ideas and bland characters, as if this were somehow the general consensus among film aficionados. "ferngully in space" or "dances with wolves with blue cat-people" are some of the kinder descriptions the film has to endure - which in all honesty i don\'t get.i mean, it\'s fine not to like the movie (all art is subjective and all t
# ...

# %%
import re

tokens = re.findall(r'\b\w+\b', text_data)
tokens
# Out:
# ['i',
#  'm',
#  'not',
#  'exactly',
#  'sure',
#  'when',
#  'it',
#  'became',
#  'a',
#  'thing',
#  'among',
#  'my',
#  'tribe',
#  'of',
#  'film',
#  'geeks',
#  'to',
#  'bash',
#  'avatar',
#  'i',
#  'know',
#  'it',
#  'wasn',
#  't',
#  'when',
#  'it',
#  'came',
#  'out',
#  'because',
#  'most',
#  'of',
#  'the',
#  'film',
#  'fans',
#  'in',
#  'my',
#  'circle',
#  'of',
#  'nerdy',
#  'friends',
#  'went',
#  'to',
#  'watch',
#  'it',
#  'multiple',
#  'times',
#  'and',
#  'couldn',
#  't',
#  'get',
#  'enough',
#  'of',
#  'it',
#  'in',
#  'hindsight',
#  'i',
#  'suspect',
#  'it',
#  'was',
#  'around',
#  'the',
#  'time',
#  'when',
#  'everybody',
#  'and',
#  'their',
#  'grandmother',
#  'seemed',
#  'to',
#  'have',
#  'seen',
#  'it',
#  'somehow',
#  'once',
#  'the',
#  'film',
#  'had',
#  'become',
#  'the',
#  'most',
#  'successful',
#  'movie',
#  'ever',
#  'unadjusted',
#  'for',
#  'inflation',
#  'it',
#  'stopped',
#  'being',
# ...

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word not in stop_words]
filtered_tokens
# Out:
# ['exactly',
#  'sure',
#  'became',
#  'thing',
#  'among',
#  'tribe',
#  'film',
#  'geeks',
#  'bash',
#  'avatar',
#  'know',
#  'came',
#  'film',
#  'fans',
#  'circle',
#  'nerdy',
#  'friends',
#  'went',
#  'watch',
#  'multiple',
#  'times',
#  'get',
#  'enough',
#  'hindsight',
#  'suspect',
#  'around',
#  'time',
#  'everybody',
#  'grandmother',
#  'seemed',
#  'seen',
#  'somehow',
#  'film',
#  'become',
#  'successful',
#  'movie',
#  'ever',
#  'unadjusted',
#  'inflation',
#  'stopped',
#  'cool',
#  'like',
#  'james',
#  'cameron',
#  'eco',
#  'sci',
#  'fi',
#  'extravaganza',
#  'nowadays',
#  'film',
#  'often',
#  'brought',
#  'snarky',
#  'movie',
#  'blogs',
#  'typical',
#  'example',
#  'film',
#  'great',
#  'effects',
#  'dull',
#  'story',
#  'unoriginal',
#  'ideas',
#  'bland',
#  'characters',
#  'somehow',
#  'general',
#  'consensus',
#  'among',
#  'film',
#  'aficionados',
#  'ferngully',
#  'space',
#  'dances',
#  'wolves',
#  'blue',
# ...

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
stemmed_tokens = [stemmer.stem(word) for word in filtered_tokens]
stemmed_tokens
# Out:
# ['exactli',
#  'sure',
#  'becam',
#  'thing',
#  'among',
#  'tribe',
#  'film',
#  'geek',
#  'bash',
#  'avatar',
#  'know',
#  'came',
#  'film',
#  'fan',
#  'circl',
#  'nerdi',
#  'friend',
#  'went',
#  'watch',
#  'multipl',
#  'time',
#  'get',
#  'enough',
#  'hindsight',
#  'suspect',
#  'around',
#  'time',
#  'everybodi',
#  'grandmoth',
#  'seem',
#  'seen',
#  'somehow',
#  'film',
#  'becom',
#  'success',
#  'movi',
#  'ever',
#  'unadjust',
#  'inflat',
#  'stop',
#  'cool',
#  'like',
#  'jame',
#  'cameron',
#  'eco',
#  'sci',
#  'fi',
#  'extravaganza',
#  'nowaday',
#  'film',
#  'often',
#  'brought',
#  'snarki',
#  'movi',
#  'blog',
#  'typic',
#  'exampl',
#  'film',
#  'great',
#  'effect',
#  'dull',
#  'stori',
#  'unorigin',
#  'idea',
#  'bland',
#  'charact',
#  'somehow',
#  'gener',
#  'consensu',
#  'among',
#  'film',
#  'aficionado',
#  'ferngulli',
#  'space',
#  'danc',
#  'wolv',
#  'blue',
#  'cat',
#  'peopl',
#  'kinder',
#  'descript',
# ...

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]
lemmatized_tokens
# Out:
# ['exactly',
#  'sure',
#  'became',
#  'thing',
#  'among',
#  'tribe',
#  'film',
#  'geek',
#  'bash',
#  'avatar',
#  'know',
#  'came',
#  'film',
#  'fan',
#  'circle',
#  'nerdy',
#  'friend',
#  'went',
#  'watch',
#  'multiple',
#  'time',
#  'get',
#  'enough',
#  'hindsight',
#  'suspect',
#  'around',
#  'time',
#  'everybody',
#  'grandmother',
#  'seemed',
#  'seen',
#  'somehow',
#  'film',
#  'become',
#  'successful',
#  'movie',
#  'ever',
#  'unadjusted',
#  'inflation',
#  'stopped',
#  'cool',
#  'like',
#  'james',
#  'cameron',
#  'eco',
#  'sci',
#  'fi',
#  'extravaganza',
#  'nowadays',
#  'film',
#  'often',
#  'brought',
#  'snarky',
#  'movie',
#  'blog',
#  'typical',
#  'example',
#  'film',
#  'great',
#  'effect',
#  'dull',
#  'story',
#  'unoriginal',
#  'idea',
#  'bland',
#  'character',
#  'somehow',
#  'general',
#  'consensus',
#  'among',
#  'film',
#  'aficionado',
#  'ferngully',
#  'space',
#  'dance',
#  'wolf',
#  'blue',
#  'cat',
# ...

# %%
from collections import Counter

word_freq = Counter(lemmatized_tokens)
word_freq
# Out:
# Counter({'exactly': 5,
#          'sure': 11,
#          'became': 2,
#          'thing': 12,
#          'among': 2,
#          'tribe': 1,
#          'film': 116,
#          'geek': 2,
#          'bash': 1,
#          'avatar': 94,
#          'know': 12,
#          'came': 5,
#          'fan': 5,
#          'circle': 1,
#          'nerdy': 1,
#          'friend': 3,
#          'went': 3,
#          'watch': 5,
#          'multiple': 2,
#          'time': 30,
#          'get': 28,
#          'enough': 13,
#          'hindsight': 1,
#          'suspect': 2,
#          'around': 6,
#          'everybody': 1,
#          'grandmother': 1,
#          'seemed': 2,
#          'seen': 21,
#          'somehow': 2,
#          'become': 5,
#          'successful': 4,
#          'movie': 67,
#          'ever': 16,
#          'unadjusted': 1,
#          'inflation': 1,
#          'stopped': 1,
#          'cool': 3,
#          'like': 44,
#          'james': 26,
#          'cameron': 62,
# ...

# %%
from collections import Counter

word_freq = Counter(lemmatized_tokens)

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(width = 500, height = 500, 
                      stopwords = stop_words, 
                      min_font_size = 10).generate_from_frequencies(word_freq)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(width = 800, height = 500, 
                      stopwords = stop_words, 
                      min_font_size = 10).generate_from_frequencies(word_freq)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(width = 1200, height = 700, 
                      stopwords = stop_words, 
                      min_font_size = 10).generate_from_frequencies(word_freq)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(width = 2000, height = 700, 
                      stopwords = stop_words, 
                      min_font_size = 10).generate_from_frequencies(word_freq)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(width = 1000, height = 1000, 
                      background_color ='blue', 
                      stopwords = stop_words, 
                      min_font_size = 10).generate_from_frequencies(word_freq)

plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 

plt.show()
